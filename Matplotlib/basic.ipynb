# %% [markdown]
# ### Basic

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 7, 3, 9]
plt.title("basic plot")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid(True)
plt.plot(x, y)
plt.show()
