# %% [markdown]
# ##String Manipulation in Pandas

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah","Sakib"],
    "City": ["New York", "Los Angeles", "Newark", "Boston", "New Delhi", "Chicago", "New Orleans", "Houston","H Los Ang"],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "Marketing", "Finance", "HR", "HR"],
    "Salary": [50000, 60000, 55000, 70000, 52000, 58000, 62000, 51000,70000]
}

df = pd.DataFrame(data)

df
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 3    David       Boston         IT   70000
# 4      Eve    New Delhi         HR   52000
# 5    Frank      Chicago  Marketing   58000
# 6    Grace  New Orleans    Finance   62000
# 7   Hannah      Houston         HR   51000
# 8    Sakib    H Los Ang         HR   70000

# %%
#case sensitive
df.loc[df["City"].str.contains("New")]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000

# %%
#without case sensitive
df.loc[df["City"].str.contains("new",case=False)]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000

# %%
# find the name start with Los
# ^ → match at start

df.loc[df["City"].str.contains(r"^Los")]
# Out:
#   Name         City Department  Salary
# 1  Bob  Los Angeles         IT   60000

# %%
#end with rk
# $ → match at end
df.loc[df["City"].str.contains(r"rk$")]
# Out:
#       Name      City Department  Salary
# 0    Alice  New York         HR   50000
# 2  Charlie    Newark    Finance   55000

# %%
#name start with a vowel
df.loc[df["Name"].str.contains(r"^[AEIOU]")]
# Out:
#     Name       City Department  Salary
# 0  Alice   New York         HR   50000
# 4    Eve  New Delhi         HR   52000

# %%
# string contains new or los

df.loc[df["City"].str.contains(r"New|Los")]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000
# 8    Sakib    H Los Ang         HR   70000

# %% [markdown]
# ##Adding New Column

# %%
df = pd.read_csv('student_data.csv')
df.tail()
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016  Ziaur Rahman                  94.0             94.0
# 16    PH1017   Afsana Mimi                  90.0             90.0
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
#adding a column with a constant value also for all rows
df["Country"] = "Bangladesh"
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#       Country
# 0  Bangladesh
# 1  Bangladesh
# 2  Bangladesh
# 3  Bangladesh
# 4  Bangladesh

# %%
df["Total_Marks"] = df["Data Structure Marks"]+df["Algorithm Marks"]+df["Python Marks"]
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#    Total_Marks
# 0        258.0
# 1          NaN
# 2        261.0
# 3        238.0
# 4          NaN

# %%
import numpy as np

df["A+ in ds"] = np.where(df["Data Structure Marks"]>=80,'A+','A')
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#    Total_Marks A+ in ds
# 0        258.0       A+
# 1          NaN       A+
# 2        261.0       A+
# 3        238.0        A
# 4          NaN        A

# %%
df["First Name"] = df["FullName"].str.split(" ").str[0]
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#    Total_Marks A+ in ds First Name
# 0        258.0       A+       Alif
# 1          NaN       A+     Fatima
# 2        261.0       A+      Imran
# 3        238.0        A   Jannatul
# 4          NaN        A      Kamal

# %%
#make a new csv file with new data
df.to_csv("new_student.csv")

# %% [markdown]
# ##Find unique values

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
    "City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
    "Score": [85, 90, 78, 85, 95, 90]
}

df = pd.DataFrame(data)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     85
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# unique() Gives you the actual unique values in a Series.
df["Name"].unique()
# Out:
# array(['Alice', 'Bob', 'Charlie', 'David'], dtype=object)

# %%
df1 = pd.read_csv('student_data.csv')
df1.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
# nunique()  Gives you the number of unique values
df1['Data Structure Marks'].nunique()
# Out:
# 12

# %% [markdown]
# ##Check Null

# %%
df1.isnull().head()
# Out:
#    StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0      False     False                 False            False         False
# 1      False     False                 False            False          True
# 2      False     False                 False            False         False
# 3      False     False                 False            False         False
# 4      False     False                  True             True         False
#
#    CompletionStatus  EnrollmentDate  Instructor  Location
# 0             False           False       False     False
# 1             False           False       False     False
# 2             False           False       False     False
# 3             False           False       False     False
# 4             False           False       False     False

# %%
df1['Data Structure Marks'].isnull().head() #check a series
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Data Structure Marks, dtype: bool

# %%
df1['Data Structure Marks'].notnull().head()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Data Structure Marks, dtype: bool

# %%
#hasnans returns True if that column has any NaN (missing) values
df1['Data Structure Marks'].hasnans

# %% [markdown]
# ##Handling Duplicates Values

# %%
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
    "City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
    "Score": [85, 90, 78, 70, 95, 90]
}

df = pd.DataFrame(data)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
df.duplicated()
# Out:
# 1

# %%
# deleting duplicates values 
#it's work on number
df.drop_duplicates()
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
# permanent 

df.drop_duplicates(inplace= True) 
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
#  duplicate deletion bases on a series

df.drop_duplicates(subset=['Name'])
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
# Keeps only the last occurrence of each unique "Name"
df.drop_duplicates(subset=['Name'],keep='last')
# Out:
#       Name      City  Score
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
# Keeps only the first occurrence of each unique "Name"
df.drop_duplicates(subset=['Name'],keep='first')
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
import pandas as pd
df = pd.read_csv('student_data.csv')

# %%
#df.dropna() → removes any rows with missing (NaN) values
df.dropna().head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 5    PH1006       Laila Begum                  75.0             75.0
# 7    PH1008       Nadia Islam                  81.0             81.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 5          78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 7          85.0        Completed     2024-04-22  Ms. Salma  Chattogram

# %%
#df.dropna(how='all', inplace=True) → removes rows where all values are NaN
df.dropna(how='all',inplace = True)

# %%
df.dropna(subset=['Python Marks']).head(3)
# df.dropna(subset=['Python Marks','Algorithm Marks'])
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor Location
# 0          88.0        Completed     2024-01-15  Mr. Karim    Dhaka
# 2          85.0        Completed     2024-02-10  Mr. Karim    Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma   Sylhet

# %%
#df.fillna(0) → replaces all NaN (missing) values in the DataFrame with 0
import numpy as np

df = pd.DataFrame({
    "Python": [90, np.nan, 80],
    "DS": [85, 75, np.nan]
})

df.fillna(0)
# Out:
#    Python    DS
# 0    90.0  85.0
# 1     0.0  75.0
# 2    80.0   0.0

# %%
#df['FullName'].fillna('unknown') → replaces NaN values in the string column FullName with "unknown"
df = pd.DataFrame({
    "FullName": ["Alice", None, "Bob"]
})

df['FullName'].fillna('unknown')
# Out:
# 0      Alice
# 1    unknown
# 2        Bob
# Name: FullName, dtype: object

# %% [markdown]
# ## Statistical Functions

# %%
df.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0           88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 2           85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 5           78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 7           85.0        Completed     2024-04-22  Ms. Salma  Chattogram
# 8           76.0        Completed     2024-05-16  Mr. David       Dhaka
# 9           88.0        Completed     2024-05-20  Ms. Salma      Sylhet
# 11          87.0        Completed     2024-06-14  Ms. Salma  Chattogram
# 12          79.0        Completed     2024-07-02  Mr. David       Dhaka
# 14          84.0        Completed     2024-08-18  Mr. Karim       Dhaka
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
#sum
df['Data Structure Marks'].sum()
# Out:
# 1344.0

# %%
#max and min

print(df["Data Structure Marks"].min())
print(df["Data Structure Marks"].max())
# Out:
# 72.0
# 94.0

# %%
#mean 

df["Data Structure Marks"].mean()
# Out:
# 84.0

# %%
#median
df["Data Structure Marks"].median()
# Out:
# 85.5

# %%
# mode

df["Data Structure Marks"].mode()
# Out:
# 0    75.0
# 1    85.0
# 2    86.0
# 3    88.0
# Name: Data Structure Marks, dtype: float64

# %%
#std
df["Data Structure Marks"].std()
# Out:
# 6.501281924871945

# %%
#co-reletion  matrix

df[["Data Structure Marks", "Python Marks"]].corr()
# Out:
#                       Data Structure Marks  Python Marks
# Data Structure Marks              1.000000      0.893455
# Python Marks                      0.893455      1.000000

# %%
# sum in different columns and row wise

df[["Data Structure Marks","Python Marks"]].sum(axis=1).head()
df["total marks"] = df.iloc[:,2:5].sum(axis=1)

# %% [markdown]
# ## Apply Function On Df

# %%
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#    total marks
# 0        258.0
# 1        184.0
# 2        261.0
# 3        238.0
# 4         95.0

# %%
#min and max scaling
mn = df["total marks"].min()
mx = df["total marks"].max()

df["Scaled Marks"] = df["total marks"].apply(lambda x : (x-mn)/(mx-mn))

# %%
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#    total marks  Scaled Marks
# 0        258.0      0.945055
# 1        184.0      0.673993
# 2        261.0      0.956044
# 3        238.0      0.871795
# 4         95.0      0.347985

# %%
#custom built in function

def grading_system(marks):

    if marks >=260:
        return 'A+' 
    elif marks>=250:
        return 'A' 
    else:
        return 'A-'
    
df["Grade"] = df["total marks"].apply(grading_system)

# %%
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
#
#    total marks  Scaled Marks Grade
# 0        258.0      0.945055     A
# 1        184.0      0.673993    A-
# 2        261.0      0.956044    A+
# 3        238.0      0.871795    A-
# 4         95.0      0.347985    A-
